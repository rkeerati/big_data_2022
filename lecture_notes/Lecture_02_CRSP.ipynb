# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup" data-toc-modified-id="Setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup</a></span></li><li><span><a href="#How-is-the-CRSP-data-organized?" data-toc-modified-id="How-is-the-CRSP-data-organized?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>How is the CRSP data organized?</a></span><ul class="toc-item"><li><span><a href="#All-tables-in-CRSP" data-toc-modified-id="All-tables-in-CRSP-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>All tables in CRSP</a></span></li><li><span><a href="#Primary-Keys-(PK)" data-toc-modified-id="Primary-Keys-(PK)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Primary Keys (PK)</a></span></li></ul></li><li><span><a href="#The-Stock/Securities-Files-Table-(msf-or-dsf)" data-toc-modified-id="The-Stock/Securities-Files-Table-(msf-or-dsf)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>The Stock/Securities Files Table (msf or dsf)</a></span><ul class="toc-item"><li><span><a href="#All-Variables-in-MSF" data-toc-modified-id="All-Variables-in-MSF-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>All Variables in MSF</a></span></li><li><span><a href="#Extra-Identifiers:-names-table" data-toc-modified-id="Extra-Identifiers:-names-table-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Extra Identifiers: names table</a></span></li><li><span><a href="#Which-firm-identifier-to-use?" data-toc-modified-id="Which-firm-identifier-to-use?-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Which firm identifier to use?</a></span></li><li><span><a href="#Difference-between-header-information-and-historical-information" data-toc-modified-id="Difference-between-header-information-and-historical-information-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Difference between header information and historical information</a></span></li><li><span><a href="#Variables-of-interest" data-toc-modified-id="Variables-of-interest-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Variables of interest</a></span></li></ul></li><li><span><a href="#The-Stock/Security-Events-(mse,-mseall,-dse,-dseall)" data-toc-modified-id="The-Stock/Security-Events-(mse,-mseall,-dse,-dseall)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>The Stock/Security Events (mse, mseall, dse, dseall)</a></span><ul class="toc-item"><li><span><a href="#All-variables-in-MSEALL" data-toc-modified-id="All-variables-in-MSEALL-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>All variables in MSEALL</a></span></li><li><span><a href="#Variables-of-Interest" data-toc-modified-id="Variables-of-Interest-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Variables of Interest</a></span></li><li><span><a href="#Check-Primary-Key" data-toc-modified-id="Check-Primary-Key-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Check Primary Key</a></span></li><li><span><a href="#DISTCD-causes-duplicates" data-toc-modified-id="DISTCD-causes-duplicates-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>DISTCD causes duplicates</a></span></li></ul></li><li><span><a href="#Merge-MSF-and-MSEALL" data-toc-modified-id="Merge-MSF-and-MSEALL-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Merge MSF and MSEALL</a></span></li><li><span><a href="#Calculate-Variables-of-Interest" data-toc-modified-id="Calculate-Variables-of-Interest-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Calculate Variables of Interest</a></span><ul class="toc-item"><li><span><a href="#Adjusted-Returns" data-toc-modified-id="Adjusted-Returns-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Adjusted Returns</a></span></li><li><span><a href="#Market-Equity-Value" data-toc-modified-id="Market-Equity-Value-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Market Equity Value</a></span><ul class="toc-item"><li><span><a href="#Can-prices-be-negative?" data-toc-modified-id="Can-prices-be-negative?-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Can prices be negative?</a></span></li><li><span><a href="#Can-number-of-shares-outstanding-be-negative?" data-toc-modified-id="Can-number-of-shares-outstanding-be-negative?-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Can number of shares outstanding be negative?</a></span></li><li><span><a href="#Create-Market-Equity-(ME)" data-toc-modified-id="Create-Market-Equity-(ME)-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Create Market Equity (ME)</a></span></li><li><span><a href="#Adjusting-for-Stock-Splits-and-Other-Corporate-Actions" data-toc-modified-id="Adjusting-for-Stock-Splits-and-Other-Corporate-Actions-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>Adjusting for Stock Splits and Other Corporate Actions</a></span></li></ul></li><li><span><a href="#ME-Lag" data-toc-modified-id="ME-Lag-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>ME Lag</a></span></li><li><span><a href="#Rankyear" data-toc-modified-id="Rankyear-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Rankyear</a></span></li></ul></li><li><span><a href="#Add-Risk-Free" data-toc-modified-id="Add-Risk-Free-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Add Risk Free</a></span></li><li><span><a href="#Save-Output" data-toc-modified-id="Save-Output-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Save Output</a></span></li></ul></div>

# %% [markdown]
# # Big Data in Finance: Part III<BR><BR> Lecture 2: CRSP
#
# **Instructor** <BR>
# Ritt Keerati, ritt.keerati@gsb.columbia.edu
#
# **TA's:** <BR>
# Meha Sadasivam, MSadasivam21@gsb.columbia.edu <BR>
# Daheng Yang, dyang22@gsb.columbia.edu <BR>
#
#
# <sub> Credit: lecture notes originally developed by Lira Mota

# %% [markdown]
# # CRSP
#
# In this section we are going to:
# 1. Download and understand the basics of CRSP tables:
#     1. Monthly Stock Files (MSF)
#     2. Monthly Stock Events (MSE)
#     2. Risk free rates (MCTI)

# %% [markdown]
# 2. Create one data frame with the following variables:
#     1. Stock exchange code
#     2. Security code (e.g, common stock, ADR)
#     3. Stock monthly returns (want to include dividend)
#     4. Market Equity Value (AMT*PRC)
#     5. Risk Free Rate

# %% [markdown]
#
# 3. Add variables:
#     1. Rankyear - Fama and French yearly rebalancing schedule
#     2. Returns adjusted for delisting
#     3. ME by PERMCO
#     4. ME lag (used for portfolios weights)
#     5. Cumulative past 11 months returns (used to calculate momentum portfolios - homework)

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline 

# Packages 
import wrds
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import time
from time import strptime, strftime

# Setups
plt.rcParams['figure.figsize'] = [10, 6]
pd.set_option("display.max_rows", 100) # max number of rows to be displayed

# %%
# Set WRDS Connection
db = wrds.Connection(wrds_username='rkeerati') # make sure to configure wrds connector before hand
# Out:
# Loading library list...
# Done

# %% [markdown]
# ## How is the CRSP data organized?

# %%
libs = db.list_libraries()
# Transform crsp_tables to a Pandas data frame to have a better display
libs = pd.DataFrame({'libs':libs}).sort_values('libs')
libs.reset_index(drop=True) 
libs.head(20)
# Out:
#                 libs
# 0                aha
# 1         aha_sample
# 2            ahasamp
# 3              audit
# 4      audit_acct_os
# 5   audit_audit_comp
# 6       audit_common
# 7   audit_corp_legal
# 8           auditsmp
# 9       auditsmp_all
# 10              bank
# 11              blab
# 12             block
# 13         block_all
# 14           boardex
# 15       boardex_eur
# 16        boardex_na
# 17       boardex_row
# 18     boardex_trial
# 19        boardex_uk

# %% [markdown]
# ### All tables in CRSP

# %%
# crspq: CRSP quartely update
crsp_tables = db.list_tables(library="crsp")
# crspm: CRSP monthly update - not included in our subscription

# Transform crsp_tables to a Pandas data frame to have a better display
crsp_tables = pd.DataFrame({'tables':crsp_tables}).sort_values('tables').reset_index(drop=True)
crsp_tables.head(20)
# Out:
#         tables
# 0         acti
# 1         asia
# 2         asib
# 3         asic
# 4         asio
# 5         asix
# 6       bmdebt
# 7     bmheader
# 8     bmpaymts
# 9     bmquotes
# 10     bmyield
# 11    bndprt06
# 12    bndprt12
# 13    bxcalind
# 14    bxdlyind
# 15    bxmthind
# 16    bxquotes
# 17     bxyield
# 18         cap
# 19  ccm_lookup

# %% [markdown]
# We are going to focus on three tables:
#
# 1. MSF: Monthly Stock Files
# 2. MSE: Monthly Stock Events
# 3. MCTI: US Treasury and Inflation - Monthly
#
# Nice overview can be found [here](https://wrds-www.wharton.upenn.edu/pages/support/manuals-and-overviews/crsp/stocks-and-indices/overview-crsp-us-stock-database/).

# %% [markdown]
# ### Primary Keys (PK)
#
# * Company identifier: PERMCO
# * Security identifier: PERMNO
# * Date: monthly or daily

# %% [markdown]
# ## The Stock/Securities Files Table (msf or dsf)

# %% [markdown]
# ### All Variables in MSF

# %%
db.describe_table(library="crsp", table="msf")
# Out:
# Approximately 4805423 rows in crsp.msf.
#         name  nullable              type
# 0      cusip      True        VARCHAR(8)
# 1     permno      True  DOUBLE_PRECISION
# 2     permco      True  DOUBLE_PRECISION
# 3     issuno      True  DOUBLE_PRECISION
# 4      hexcd      True  DOUBLE_PRECISION
# 5     hsiccd      True  DOUBLE_PRECISION
# 6       date      True              DATE
# 7      bidlo      True  DOUBLE_PRECISION
# 8      askhi      True  DOUBLE_PRECISION
# 9        prc      True  DOUBLE_PRECISION
# 10       vol      True  DOUBLE_PRECISION
# 11       ret      True  DOUBLE_PRECISION
# 12       bid      True  DOUBLE_PRECISION
# 13       ask      True  DOUBLE_PRECISION
# 14    shrout      True  DOUBLE_PRECISION
# 15    cfacpr      True  DOUBLE_PRECISION
# 16   cfacshr      True  DOUBLE_PRECISION
# 17    altprc      True  DOUBLE_PRECISION
# 18    spread      True  DOUBLE_PRECISION
# 19  altprcdt      True              DATE
# 20      retx      True  DOUBLE_PRECISION

# %% [markdown]
# ### Extra Identifiers: names table

# %%
db.describe_table(library="crsp", table="stocknames")
# Out:
# Approximately 75354 rows in crsp.stocknames.
#          name  nullable              type
# 0      permno      True  DOUBLE_PRECISION
# 1      permco      True  DOUBLE_PRECISION
# 2      namedt      True              DATE
# 3   nameenddt      True              DATE
# 4       cusip      True        VARCHAR(8)
# 5      ncusip      True        VARCHAR(8)
# 6      ticker      True        VARCHAR(8)
# 7      comnam      True       VARCHAR(35)
# 8       hexcd      True  DOUBLE_PRECISION
# 9      exchcd      True  DOUBLE_PRECISION
# 10      siccd      True  DOUBLE_PRECISION
# 11      shrcd      True  DOUBLE_PRECISION
# 12     shrcls      True        VARCHAR(4)
# 13    st_date      True              DATE
# 14   end_date      True              DATE
# 15    namedum      True  DOUBLE_PRECISION

# %% [markdown]
# ### Which firm identifier to use?
#
# * PERMCO?
# * PERMNO?
# * CUSIP?
# * NCUSIP?

# %%
# An example of name change
names_table = db.raw_sql('SELECT * FROM crsp.stocknames')

# Google
# 62822  1999-03-31  2001-08-31      2.0
# 64818  2000-04-28  2001-07-31      2.0
# 64819  2000-04-28  2001-07-31      2.0

# %% [markdown]
# ### Difference between header information and historical information
#
# * Usually "h" in CRSP means header - a static characteristic. Either the most recent observation (hsiccd) or as the time the security was listed (hexcd).
# * Historical data: siccd, excd, etc.
# * Notice that for CUSIP it is different. Historical cusip is under NCUSIP.

# %% [markdown]
# ### Variables of interest
#
# 1. Identifiers: date, permno, permco
# 2. Price: prc
# 3. Return: ret
# 4. Return Ex-dividend: retx
# 5. Factor to adjust prices and shares outstading: 'cfacpr'/'cfacshr'
#
#
# Where to find variable definitions? [WRDS website](https://wrds-www.wharton.upenn.edu/documents/396/CRSP_US_Stock_Indices_Data_Descriptions.pdf).

# %%
sfvars = ['prc','vol','ret', 'retx','cfacpr','cfacshr']
query = """SELECT date, permno, permco, {} 
           FROM crsp.msf
           WHERE date>='1980-01-01'""".format(', '.join(sfvars))
print(query)
# Out:
# SELECT date, permno, permco, prc, vol, ret, retx, cfacpr, cfacshr
#            FROM crsp.msf
#            WHERE date>='1980-01-01'

# %%
msf_data = db.raw_sql(query, date_cols=['date'])
del(sfvars, query)

# %% [markdown]
# **Look at the data**

# %%
msf_data.head()
# Out:
#         date   permno  permco     prc     vol       ret      retx  cfacpr  \
# 0 1985-12-31  10000.0  7952.0     NaN     NaN       NaN       NaN     NaN
# 1 1986-01-31  10000.0  7952.0 -4.3750  1771.0       NaN       NaN     1.0
# 2 1986-02-28  10000.0  7952.0 -3.2500   828.0 -0.257143 -0.257143     1.0
# 3 1986-03-31  10000.0  7952.0 -4.4375  1078.0  0.365385  0.365385     1.0
# 4 1986-04-30  10000.0  7952.0 -4.0000   957.0 -0.098592 -0.098592     1.0
#
#    cfacshr
# 0      NaN
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0

# %%
# Check if we have a primary key
msf_data.duplicated(subset=['permno', 'date']).sum()
# Out:
# 0

# %%
msf_data.groupby(['permco', 'date']).permno.nunique().mean()
# Out:
# 1.0872396283578

# %%
msf_data.groupby(['permco', 'date']).permno.nunique().max()
# Out:
# 311

# %%
# Cumulative returns of Apple 
apple_ret = msf_data[msf_data.permno==14593].set_index(['date']).ret
((1+apple_ret).cumprod()).plot(title='Cumulative Returns of Apple')
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns of Apple'}, xlabel='date'>

# %% [markdown]
# ## The Stock/Security Events (mse, mseall, dse, dseall)

# %% [markdown]
# ### All variables in MSEALL

# %%
db.describe_table(library="crspq", table="mseall")
# Out:
# Approximately 3416169 rows in crspq.mseall.
#         name  nullable              type
# 0       date      True              DATE
# 1     comnam      True       VARCHAR(32)
# 2      cusip      True        VARCHAR(8)
# 3     dclrdt      True              DATE
# 4      dlamt      True  DOUBLE_PRECISION
# 5      dlpdt      True              DATE
# 6     dlstcd      True  DOUBLE_PRECISION
# 7     hsiccd      True  DOUBLE_PRECISION
# 8     issuno      True  DOUBLE_PRECISION
# 9     ncusip      True        VARCHAR(8)
# 10    nextdt      True              DATE
# 11     paydt      True              DATE
# 12    rcrddt      True              DATE
# 13    shrcls      True        VARCHAR(1)
# 14    shrflg      True  DOUBLE_PRECISION
# 15    ticker      True        VARCHAR(5)
# 16    permno      True  DOUBLE_PRECISION
# 17    permco      True  DOUBLE_PRECISION
# 18     hexcd      True  DOUBLE_PRECISION
# 19    hsicmg      True  DOUBLE_PRECISION
# 20    hsicig      True  DOUBLE_PRECISION
# 21  nameendt      True              DATE
# 22     shrcd      True  DOUBLE_PRECISION
# 23    exchcd      True  DOUBLE_PRECISION
# 24     siccd      True  DOUBLE_PRECISION
# 25   tsymbol      True       VARCHAR(10)
# 26     naics      True        VARCHAR(7)
# 27  primexch      True        VARCHAR(1)
# 28   trdstat      True        VARCHAR(1)
# 29   secstat      True        VARCHAR(1)
# 30    distcd      True  DOUBLE_PRECISION
# 31    divamt      True  DOUBLE_PRECISION
# 32     facpr      True  DOUBLE_PRECISION
# 33    facshr      True  DOUBLE_PRECISION
# 34    acperm      True  DOUBLE_PRECISION
# 35    accomp      True  DOUBLE_PRECISION
# 36    shrout      True  DOUBLE_PRECISION
# 37  shrenddt      True              DATE
# 38    nwperm      True  DOUBLE_PRECISION
# 39    nwcomp      True  DOUBLE_PRECISION
# 40    dlretx      True  DOUBLE_PRECISION
# 41     dlprc      True  DOUBLE_PRECISION
# 42     dlret      True  DOUBLE_PRECISION
# 43    trtscd      True  DOUBLE_PRECISION
# 44  trtsendt      True              DATE
# 45    nmsind      True  DOUBLE_PRECISION
# 46     mmcnt      True  DOUBLE_PRECISION
# 47    nsdinx      True  DOUBLE_PRECISION
# 48      year      True  DOUBLE_PRECISION
# 49     month      True  DOUBLE_PRECISION

# %% [markdown]
# ### Variables of Interest
# 1. Delisting returns: dlret, dlretx
# 2. Exchange codes: exchcd - 1 (NYSE), 2 (NYSE MKT), 3 (NASDAQ), 4 (Arca) or 5 (Bats).
# 3. Share Type Code: shrcd (usually we only look at Ordinary Common Shares, 10 and 11)
# 4. Industry classifications: siccd, naics
# 5. Stock Ticker

# %%
msevars = ['dlret', 'dlretx', 'exchcd','naics', 'ncusip', 'shrcd', 'shrout', 
           'siccd','comnam','ticker','distcd']
query = """SELECT date, permno, permco, {} 
           FROM crsp.mseall
           WHERE date>='1980-01-01'""".format(', '.join(msevars))
print(query)
# Out:
# SELECT date, permno, permco, dlret, dlretx, exchcd, naics, ncusip, shrcd, shrout, siccd, comnam, ticker, distcd
#            FROM crsp.mseall
#            WHERE date>='1980-01-01'

# %%
# Look at columns you could download 
db.describe_table(library="crsp", table="mseall")
# Out:
# Approximately 3416169 rows in crsp.mseall.
#         name  nullable              type
# 0       date      True              DATE
# 1     comnam      True       VARCHAR(32)
# 2      cusip      True        VARCHAR(8)
# 3     dclrdt      True              DATE
# 4      dlamt      True  DOUBLE_PRECISION
# 5      dlpdt      True              DATE
# 6     dlstcd      True  DOUBLE_PRECISION
# 7     hsiccd      True  DOUBLE_PRECISION
# 8     issuno      True  DOUBLE_PRECISION
# 9     ncusip      True        VARCHAR(8)
# 10    nextdt      True              DATE
# 11     paydt      True              DATE
# 12    rcrddt      True              DATE
# 13    shrcls      True        VARCHAR(1)
# 14    shrflg      True  DOUBLE_PRECISION
# 15    ticker      True        VARCHAR(5)
# 16    permno      True  DOUBLE_PRECISION
# 17    permco      True  DOUBLE_PRECISION
# 18     hexcd      True  DOUBLE_PRECISION
# 19    hsicmg      True  DOUBLE_PRECISION
# 20    hsicig      True  DOUBLE_PRECISION
# 21  nameendt      True              DATE
# 22     shrcd      True  DOUBLE_PRECISION
# 23    exchcd      True  DOUBLE_PRECISION
# 24     siccd      True  DOUBLE_PRECISION
# 25   tsymbol      True       VARCHAR(10)
# 26     naics      True        VARCHAR(7)
# 27  primexch      True        VARCHAR(1)
# 28   trdstat      True        VARCHAR(1)
# 29   secstat      True        VARCHAR(1)
# 30    distcd      True  DOUBLE_PRECISION
# 31    divamt      True  DOUBLE_PRECISION
# 32     facpr      True  DOUBLE_PRECISION
# 33    facshr      True  DOUBLE_PRECISION
# 34    acperm      True  DOUBLE_PRECISION
# 35    accomp      True  DOUBLE_PRECISION
# 36    shrout      True  DOUBLE_PRECISION
# 37  shrenddt      True              DATE
# 38    nwperm      True  DOUBLE_PRECISION
# 39    nwcomp      True  DOUBLE_PRECISION
# 40    dlretx      True  DOUBLE_PRECISION
# 41     dlprc      True  DOUBLE_PRECISION
# 42     dlret      True  DOUBLE_PRECISION
# 43    trtscd      True  DOUBLE_PRECISION
# 44  trtsendt      True              DATE
# 45    nmsind      True  DOUBLE_PRECISION
# 46     mmcnt      True  DOUBLE_PRECISION
# 47    nsdinx      True  DOUBLE_PRECISION
# 48      year      True  DOUBLE_PRECISION
# 49     month      True  DOUBLE_PRECISION

# %%
mse_data = db.raw_sql(query, date_cols=['date'])
del(msevars, query)

# %% [markdown]
# **Look at the data**

# %%
mse_data[mse_data.permno==14593]
# Out:
#              date   permno  permco  dlret  dlretx  exchcd   naics    ncusip  \
# 371549 1980-12-31  14593.0     7.0    NaN     NaN     3.0    None  03783310
# 371550 1981-06-30  14593.0     7.0    NaN     NaN     3.0    None  03783310
# 371551 1981-09-30  14593.0     7.0    NaN     NaN     3.0    None  03783310
# 371552 1981-12-31  14593.0     7.0    NaN     NaN     3.0    None  03783310
# 371553 1982-03-31  14593.0     7.0    NaN     NaN     3.0    None  03783310
# ...           ...      ...     ...    ...     ...     ...     ...       ...
# 372019 2021-08-31  14593.0     7.0    NaN     NaN     3.0  334220  03783310
# 372020 2021-09-30  14593.0     7.0    NaN     NaN     3.0  334220  03783310
# 372021 2021-10-29  14593.0     7.0    NaN     NaN     3.0  334220  03783310
# 372022 2021-11-30  14593.0     7.0    NaN     NaN     3.0  334220  03783310
# 372023 2021-12-31  14593.0     7.0    NaN     NaN     3.0  334220  03783310
#
#         shrcd      shrout   siccd              comnam ticker  distcd
# 371549   11.0     55136.0  3573.0  APPLE COMPUTER INC   AAPL     NaN
# 371550   11.0     55136.0  3573.0  APPLE COMPUTER INC   AAPL     NaN
# 371551   11.0     55309.0  3573.0  APPLE COMPUTER INC   AAPL     NaN
# 371552   11.0     55421.0  3573.0  APPLE COMPUTER INC   AAPL     NaN
# 371553   11.0     56488.0  3573.0  APPLE COMPUTER INC   AAPL     NaN
# ...       ...         ...     ...                 ...    ...     ...
# 372019   11.0  16530166.0  3571.0           APPLE INC   AAPL  1232.0
# 372020   11.0  16426786.0  3571.0           APPLE INC   AAPL     NaN
# 372021   11.0  16406397.0  3571.0           APPLE INC   AAPL     NaN
# 372022   11.0  16406397.0  3571.0           APPLE INC   AAPL  1232.0
# 372023   11.0  16406397.0  3571.0           APPLE INC   AAPL     NaN
#
# [475 rows x 14 columns]

# %% [markdown]
# ### Check Primary Key

# %%
# Check Primary Key
mse_data.duplicated(subset=['date','permno']).sum()
# Out:
# 34192

# %%
# Check Duplicates
mse_data[mse_data.duplicated(subset=['date','permno'])]
# Out:
#             date   permno   permco  dlret  dlretx  exchcd   naics    ncusip  \
# 59    1994-06-30  10001.0   7953.0    NaN     NaN     3.0    None  29274A10
# 197   2008-02-29  10001.0   7953.0    NaN     NaN     3.0  221210  29274A20
# 351   1993-12-31  10002.0   7954.0    NaN     NaN     3.0    None  83623410
# 1811  1986-12-31  10020.0   7972.0    NaN     NaN     3.0    None  49307510
# 1830  1988-12-30  10020.0   7972.0    NaN     NaN     3.0    None  49307510
# ...          ...      ...      ...    ...     ...     ...     ...       ...
# 69574 2010-12-31  93413.0  51187.0    NaN     NaN     4.0  525990  18383M88
# 69575 2010-12-31  93413.0  51187.0    NaN     NaN     4.0  525990  18383M88
# 69968 2010-12-31  93417.0  53120.0    NaN     NaN     4.0  525990  37950E78
# 70521 2020-12-31  93421.0  52902.0    NaN     NaN     4.0  525990  46138E63
# 70534 2021-12-31  93421.0  52902.0    NaN     NaN     4.0  525990  46138E63
#
#        shrcd   shrout   siccd                            comnam ticker  distcd
# 59      11.0   2191.0  4920.0                   ENERGY WEST INC   EWST  5523.0
# 197     11.0   4345.0  4920.0                   ENERGY WEST INC   EWST  1222.0
# 351     11.0   2999.0  6710.0  SOUTH ALABAMA BANCORPORATION INC   SABC  1272.0
# 1811    11.0   5800.0  6710.0          KEY CENTURION BANCSHARES   KEYC  1212.0
# 1830    11.0  20281.0  6710.0          KEY CENTURION BANCSHARES   KEYC  1232.0
# ...      ...      ...     ...                               ...    ...     ...
# 69574   73.0   1100.0  6726.0              CLAYMORE E T F TRUST   BSCB  1272.0
# 69575   73.0   1100.0  6726.0              CLAYMORE E T F TRUST   BSCB  2216.0
# 69968   73.0   1800.0  6726.0                    GLOBAL X FUNDS   BRAZ  2216.0
# 70521   73.0   4450.0  6726.0            INVESCO E T F TRUST II   PICB  2216.0
# 70534   73.0   5650.0  6726.0            INVESCO E T F TRUST II   PICB  2216.0
#
# [34192 rows x 14 columns]

# %%
mse_data[(mse_data.permno==10001)&(mse_data.date=='2008-02-29')]
# Out:
#           date   permno  permco  dlret  dlretx  exchcd   naics    ncusip  \
# 196 2008-02-29  10001.0  7953.0    NaN     NaN     3.0  221210  29274A20
# 197 2008-02-29  10001.0  7953.0    NaN     NaN     3.0  221210  29274A20
#
#      shrcd  shrout   siccd           comnam ticker  distcd
# 196   11.0  4345.0  4920.0  ENERGY WEST INC   EWST  5523.0
# 197   11.0  4345.0  4920.0  ENERGY WEST INC   EWST  1222.0

# %% [markdown]
# ### DISTCD causes duplicates
# * DISTCD: event code that records list of events describing cash dividends, capital adjustments, and other distributions made to shareholders of a security;
# * For stock/date there might be multiple events.
# * For example, in the case of Energy West (EWST)
#     * 1222: US cash dividend, monthly, taxable same rate as dividends
#     * 5523: Stock split, non-taxable

# %%
# Redownload without distcd 
msevars = ['comnam', 'dlret', 'dlretx', 'exchcd','naics', 'cusip', 'ncusip', 'shrcd', 'shrout', 
           'siccd','ticker']
query = """SELECT date, permno, permco, {} 
           FROM crspq.mseall
           WHERE date>='1980-01-01'""".format(', '.join(msevars))
print(query)
# Out:
# SELECT date, permno, permco, comnam, dlret, dlretx, exchcd, naics, cusip, ncusip, shrcd, shrout, siccd, ticker
#            FROM crspq.mseall
#            WHERE date>='1980-01-01'

# %%
mse_data = db.raw_sql(query, date_cols=['date'])
del(msevars, query)

# %%
mse_data = mse_data[~mse_data.duplicated()].copy()

# %%
# Check primary key
mse_data.duplicated(subset=['date','permno']).sum()
# Out:
# 0

# %%
mse_data.head()
# Out:
#         date   permno  permco                     comnam  dlret  dlretx  \
# 0 1986-01-31  10000.0  7952.0  OPTIMUM MANUFACTURING INC    NaN     NaN
# 1 1986-03-31  10000.0  7952.0  OPTIMUM MANUFACTURING INC    NaN     NaN
# 2 1986-04-30  10000.0  7952.0  OPTIMUM MANUFACTURING INC    NaN     NaN
# 3 1986-05-30  10000.0  7952.0  OPTIMUM MANUFACTURING INC    NaN     NaN
# 4 1986-06-30  10000.0  7952.0  OPTIMUM MANUFACTURING INC    NaN     NaN
#
#    exchcd naics     cusip    ncusip  shrcd  shrout   siccd ticker
# 0     3.0  None  68391610  68391610   10.0  3680.0  3990.0  OMFGA
# 1     3.0  None  68391610  68391610   10.0  3680.0  3990.0  OMFGA
# 2     3.0  None  68391610  68391610   10.0  3793.0  3990.0  OMFGA
# 3     3.0  None  68391610  68391610   10.0  3793.0  3990.0  OMFGA
# 4     3.0  None  68391610  68391610   10.0  3793.0  3990.0  OMFGA

# %% [markdown]
# ## Merge MSF and MSEALL

# %% [markdown]
# When merging mse and msf tables we should copy information from event observations to succeeding non-event observations.

# %% [markdown]
# Check data types: for some reason the merge does not work for PERMNO as float

# %%
msf_data.dtypes
# Out:
# date       datetime64[ns]
# permno            float64
# permco            float64
# prc               float64
# vol               float64
# ret               float64
# retx              float64
# cfacpr            float64
# cfacshr           float64
# dtype: object

# %%
## Check data types
mse_data.dtypes
# Out:
# date      datetime64[ns]
# permno           float64
# permco           float64
# comnam            object
# dlret            float64
# dlretx           float64
# exchcd           float64
# naics             object
# cusip             object
# ncusip            object
# shrcd            float64
# shrout           float64
# siccd            float64
# ticker            object
# dtype: object

# %%
# Change Permno Data Type.
msf_data['permno'] = msf_data['permno'].astype('int')
mse_data['permno'] = mse_data['permno'].astype('int')

# %%
msf_data.sort_values(['date', 'permno'], inplace=True)
mse_data.sort_values(['date', 'permno'], inplace=True)

# %% [markdown]
# **Merge tables with following logic:**
# * For each msf observation, merge most recent mseall observation with same permno,
# * If particular permno-date combination does not exist in msf but does in mseall, do not include that observation.
#
# **How to do this?** Pandas is powerful!

# %%
from IPython.display import IFrame
IFrame('https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge_asof.html', width=900, height=400)
# Out:
#         <iframe
#             width="900"
#             height="400"
#             src="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge_asof.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Check of coverage
x = pd.Series(msf_data.permno.unique())
y = pd.Series(mse_data.permno.unique())

# Have event but no price?
x[~x.isin(y)]
# Out:
# Series([], dtype: int64)

# %%
# Have price but no event?
y[~y.isin(x)]
# Out:
# 306      30921
# 315      31544
# 359      34893
# 770      55723
# 1006     68778
# 1021     71432
# 1930     50391
# 2868     40344
# 3111     51844
# 3578     31820
# 3618     43756
# 3640     48362
# 3654     51319
# 3796     30251
# 4421     33435
# 4512     14860
# 4565     33996
# 4566     34797
# 4676     69834
# 4756     45196
# 4772     54383
# 4780     58617
# 4792     65681
# 4856     45795
# 4960     18965
# 5059     37727
# 5202     60170
# 5207     60901
# 5544     76071
# 5546     77068
# 5740     53348
# 5744     56099
# 5940     69140
# 6046     17321
# 6062     36389
# 6101     32029
# 6126     27465
# 6131     35677
# 6278     73067
# 6666     36062
# 8846     45321
# 8983     53023
# 9704     37401
# 23104    22162
# 25909    35502
# dtype: int64

# %%
# Check if delisting happens only once per security
mse_data[mse_data.dlret.notnull()].groupby(['permno']).date.value_counts().max()
# Out:
# 1

# %%
# Check if delisting returns only appears after the firm is not longer covered by msf
test = mse_data[mse_data.dlret.notnull()]
test = pd.merge(msf_data, test[['permno', 'dlret', 'date']], on=['permno'])
test[test.date_x>test.date_y]
# Out:
# Empty DataFrame
# Columns: [date_x, permno, permco, prc, vol, ret, retx, cfacpr, cfacshr, dlret, date_y]
# Index: []

# %%
crsp = pd.merge_asof(msf_data, 
                     mse_data, 
                     on='date', 
                     by=['permno','permco'], 
                     direction='backward')

# %%
crsp.columns
# Out:
# Index(['date', 'permno', 'permco', 'prc', 'vol', 'ret', 'retx', 'cfacpr',
#        'cfacshr', 'comnam', 'dlret', 'dlretx', 'exchcd', 'naics', 'cusip',
#        'ncusip', 'shrcd', 'shrout', 'siccd', 'ticker'],
#       dtype='object')

# %%
crsp[crsp.ticker=='GOOG']
# Out:
#               date  permno   permco          prc        vol       ret  \
# 2171654 2004-08-31   90319  45483.0   102.370003   669547.0       NaN
# 2178562 2004-09-30   90319  45483.0   129.600006  1066083.0  0.265996
# 2185493 2004-10-29   90319  45483.0   190.639999  2580994.0  0.470988
# 2192426 2004-11-30   90319  45483.0   181.979996  2788008.0 -0.045426
# 2199370 2004-12-31   90319  45483.0   192.789993  1457027.0  0.059402
# ...            ...     ...      ...          ...        ...       ...
# 3633679 2021-08-31   14542  45483.0  2909.239990   185695.0  0.075735
# 3642707 2021-09-30   14542  45483.0  2665.310059   251870.0 -0.083847
# 3651854 2021-10-29   14542  45483.0  2965.409912   247009.0  0.112595
# 3661103 2021-11-30   14542  45483.0  2849.040039   220565.0 -0.039242
# 3670453 2021-12-31   14542  45483.0  2893.590088   238526.0  0.015637
#
#              retx  cfacpr  cfacshr        comnam  dlret  dlretx  exchcd  \
# 2171654       NaN  1.9969      1.0    GOOGLE INC    NaN     NaN     3.0
# 2178562  0.265996  1.9969      1.0    GOOGLE INC    NaN     NaN     3.0
# 2185493  0.470988  1.9969      1.0    GOOGLE INC    NaN     NaN     3.0
# 2192426 -0.045426  1.9969      1.0    GOOGLE INC    NaN     NaN     3.0
# 2199370  0.059402  1.9969      1.0    GOOGLE INC    NaN     NaN     3.0
# ...           ...     ...      ...           ...    ...     ...     ...
# 3633679  0.075735  1.0000      1.0  ALPHABET INC    NaN     NaN     3.0
# 3642707 -0.083847  1.0000      1.0  ALPHABET INC    NaN     NaN     3.0
# 3651854  0.112595  1.0000      1.0  ALPHABET INC    NaN     NaN     3.0
# 3661103 -0.039242  1.0000      1.0  ALPHABET INC    NaN     NaN     3.0
# 3670453  0.015637  1.0000      1.0  ALPHABET INC    NaN     NaN     3.0
#
#           naics     cusip    ncusip  shrcd    shrout   siccd ticker
# 2171654  514191  02079K30  38259P50   11.0   33603.0  7375.0   GOOG
# 2178562  514191  02079K30  38259P50   11.0   57857.0  7375.0   GOOG
# 2185493  514191  02079K30  38259P50   11.0   57857.0  7375.0   GOOG
# 2192426  514191  02079K30  38259P50   11.0   57857.0  7375.0   GOOG
# 2199370  514191  02079K30  38259P50   11.0   95542.0  7375.0   GOOG
# ...         ...       ...       ...    ...       ...     ...    ...
# 3633679  334419  02079K10  02079K10   11.0  320168.0  7375.0   GOOG
# 3642707  334419  02079K10  02079K10   11.0  318620.0  7375.0   GOOG
# 3651854  334419  02079K10  02079K10   11.0  317738.0  7375.0   GOOG
# 3661103  334419  02079K10  02079K10   11.0  317738.0  7375.0   GOOG
# 3670453  334419  02079K10  02079K10   11.0  317738.0  7375.0   GOOG
#
# [209 rows x 20 columns]

# %%
# Check Primary Key
crsp.duplicated(subset=['permno','date']).sum()
# Out:
# 0

# %%
# Check Apple
crsp[crsp.permno==14593].tail()
# Out:
#               date  permno  permco         prc         vol       ret  \
# 3633706 2021-08-31   14593     7.0  151.830002  14615956.0  0.042438
# 3642734 2021-09-30   14593     7.0  141.500000  17967120.0 -0.068037
# 3651881 2021-10-29   14593     7.0  149.800003  15637134.0  0.058657
# 3661130 2021-11-30   14593     7.0  165.300003  16900358.0  0.104940
# 3670479 2021-12-31   14593     7.0  177.570007  24442196.0  0.074229
#
#              retx  cfacpr  cfacshr     comnam  dlret  dlretx  exchcd   naics  \
# 3633706  0.040930     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220
# 3642734 -0.068037     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220
# 3651881  0.058657     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220
# 3661130  0.103471     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220
# 3670479  0.074229     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220
#
#             cusip    ncusip  shrcd      shrout   siccd ticker
# 3633706  03783310  03783310   11.0  16530166.0  3571.0   AAPL
# 3642734  03783310  03783310   11.0  16426786.0  3571.0   AAPL
# 3651881  03783310  03783310   11.0  16406397.0  3571.0   AAPL
# 3661130  03783310  03783310   11.0  16406397.0  3571.0   AAPL
# 3670479  03783310  03783310   11.0  16406397.0  3571.0   AAPL

# %% [markdown]
# ## Calculate Variables of Interest

# %% [markdown]
# ### Adjusted Returns
#
# Add to the ret series the delisting returns

# %%
# Returns adjusted for delisting
crsp['retadj'] = ((1+crsp['ret'].fillna(0))*(1+crsp['dlret'].fillna(0))-1)
crsp.loc[crsp[['ret', 'dlret']].isnull().all(axis=1), 'retadj'] = np.nan

# %% [markdown]
# ### Market Equity Value

# %% [markdown]
# #### Can prices be negative?

# %%
crsp[(crsp.prc<0)]
# Out:
#               date  permno   permco         prc    vol       ret      retx  \
# 2       1980-01-31   10058     20.0   -2.500000    NaN  0.000000  0.000000
# 4       1980-01-31   10103     52.0   -1.625000    NaN  0.083333  0.083333
# 7       1980-01-31   10146    314.0  -11.000000    NaN -0.022222 -0.022222
# 9       1980-01-31   10154     81.0  -10.125000    NaN  0.350000  0.350000
# 11      1980-01-31   10162     88.0   -8.500000    NaN  0.214286  0.214286
# ...            ...     ...      ...         ...    ...       ...       ...
# 3676427 2021-12-31   80168  28392.0 -118.705002   34.0  0.057666  0.049883
# 3676634 2021-12-31   82932   4922.0  -57.404999   84.0  0.110470  0.103836
# 3677554 2021-12-31   89948  44702.0  -11.690000  188.0 -0.015388 -0.015388
# 3677638 2021-12-31   90228  45301.0  -28.625000   54.0  0.061676  0.061676
# 3678549 2021-12-31   92950  53127.0  -27.795000  185.0  0.003618  0.003618
#
#          cfacpr  cfacshr                          comnam  ...  dlretx  exchcd  \
# 2          1.00     1.00                             NaN  ...     NaN     NaN
# 4          1.00     1.00                             NaN  ...     NaN     NaN
# 7          1.50     1.50                             NaN  ...     NaN     NaN
# 9          2.25     2.25                             NaN  ...     NaN     NaN
# 11         1.00     1.00                             NaN  ...     NaN     NaN
# ...         ...      ...                             ...  ...     ...     ...
# 3676427    1.00     1.00  FEDERAL AGRICULTURAL MORT CORP  ...     NaN     1.0
# 3676634    1.00     1.00           WILEY JOHN & SONS INC  ...     NaN     1.0
# 3677554    1.00     1.00                 C K X LANDS INC  ...     NaN     2.0
# 3677638    1.00     1.00              LIBERTY GLOBAL PLC  ...     NaN     3.0
# 3678549    1.00     1.00             INDEXIQ E T F TRUST  ...     NaN     4.0
#
#           naics     cusip    ncusip shrcd   shrout   siccd  ticker    retadj
# 2           NaN       NaN       NaN   NaN      NaN     NaN     NaN  0.000000
# 4           NaN       NaN       NaN   NaN      NaN     NaN     NaN  0.083333
# 7           NaN       NaN       NaN   NaN      NaN     NaN     NaN -0.022222
# 9           NaN       NaN       NaN   NaN      NaN     NaN     NaN  0.350000
# 11          NaN       NaN       NaN   NaN      NaN     NaN     NaN  0.214286
# ...         ...       ...       ...   ...      ...     ...     ...       ...
# 3676427  522298  31314810  31314810  11.0   1031.0  6111.0     AGM  0.057666
# 3676634  511130  96822330  96822330  11.0   9054.0  2731.0      JW  0.110470
# 3677554  211120  12562N10  12562N10  11.0   1942.0  1311.0     CKX -0.015388
# 3677638  515210  G5480U11  G5480U11  12.0  12931.0  4841.0   LBTYB  0.061676
# 3678549  525990  45409B20  45409B20  73.0    150.0  6726.0    MCRO  0.003618
#
# [495872 rows x 21 columns]

# %% [markdown]
# **Why Negative Prices?**<BR><BR>
# * If the closing price is not available for any given period, the number in the price field is replaced with a bid/ask average
# * Bid/ask averages have dashes placed in front of them
# * These do not incorrectly reflect negative prices; they serve to distinguish bid/ask averages from actual closing prices. If neither the price nor bid/ask average is available, the field is set to zero

# %% [markdown]
# #### Can number of shares outstanding be negative?

# %%
(crsp.shrout<0).sum()
# Out:
# 0

# %% [markdown]
# #### Create Market Equity (ME)

# %%
# SHROUT is the number of publicly held shares, recorded in thousands. ME will be reported in 1,000,000 ($10^6$),
# Like on Ken French's website. 
crsp['me'] = abs(crsp['prc']) * (crsp['shrout']/1000)

# %%
# Also, some companies have multiple shareclasses (=PERMNOs).
# To get the company ME, we need to calculate the sum of ME over all shareclasses for one company (=PERMCO).
# This is used for sorting, but not for weights.

# Create MEsum
crsp['mesum'] = crsp.groupby(['date', 'permco']).me.transform(np.sum, min_count=1)

# %%
# If the stock is delisted, we set ME to NaN.
crsp.loc[crsp.dlret.notnull(), 'me'] = np.nan
crsp.loc[crsp.dlret.notnull(), 'mesum'] = np.nan

# %% [markdown]
# #### Adjusting for Stock Splits and Other Corporate Actions
#
# * Returns are already adjusted for splits, but prices and shares outstanding are not.
# * To adjust prices and shares outstanding, use the following use:
#     * Adjusted prices = PRC / CFACPR
#     * Adjusted shares = SHROUT * CFACSHR

# %% [markdown]
# ### ME Lag
#
# MElag is used as portfolio weights in the FF factors.

# %%
crsp.sort_values(['permno','date'], inplace=True)

# %%
crsp['melag_nt']=crsp.groupby(['permno']).me.shift(1)

# %%
#crsp[crsp.melag_nt.isna() & ~crsp.melag.isna()]
crsp[crsp.permno==10028].head(100)
# Out:
#               date  permno  permco       prc     vol       ret      retx  \
# 423439  1986-01-31   10028  7978.0       NaN     NaN       NaN       NaN
# 429954  1986-02-28   10028  7978.0 -1.125000   834.0       NaN       NaN
# 436482  1986-03-31   10028  7978.0 -1.375000   868.0  0.222222  0.222222
# 443040  1986-04-30   10028  7978.0 -1.625000  1094.0  0.181818  0.181818
# 449644  1986-05-30   10028  7978.0 -1.875000  1939.0  0.153846  0.153846
# 456324  1986-06-30   10028  7978.0 -1.625000   753.0 -0.133333 -0.133333
# 463069  1986-07-31   10028  7978.0 -0.687500  1651.0 -0.576923 -0.576923
# 469846  1986-08-29   10028  7978.0 -0.656250  2411.0 -0.045455 -0.045455
# 476649  1986-09-30   10028  7978.0 -0.625000  1097.0 -0.047619 -0.047619
# 483500  1986-10-31   10028  7978.0 -0.687500   455.0  0.100000  0.100000
# 490401  1986-11-28   10028  7978.0 -0.625000   225.0 -0.090909 -0.090909
# 497360  1986-12-31   10028  7978.0 -0.500000   658.0 -0.200000 -0.200000
# 504326  1987-01-30   10028  7978.0 -0.500000   495.0  0.000000  0.000000
# 511279  1987-02-27   10028  7978.0 -0.500000   300.0  0.000000  0.000000
# 518273  1987-03-31   10028  7978.0 -0.687500  1128.0  0.375000  0.375000
# 525328  1987-04-30   10028  7978.0 -0.906250   472.0  0.318182  0.318182
# 532435  1987-05-29   10028  7978.0 -0.906250  1503.0  0.000000  0.000000
# 1043902  10.548750   8.790625
# 1051344   9.044750  10.548750
# 1058860  10.784125   9.044750
# 1066433  10.436250  10.784125
# 1074053   9.740500  10.436250
# 1081750  12.175625   9.740500
# 1089555  10.436250  12.175625
# 1097492  13.567125  10.436250
# 1105482  14.610750  13.567125
# 1113518  16.350125  14.610750
# 1121625  13.567125  16.350125
# 1129772  15.306500  13.567125
#
# [100 rows x 24 columns]

# %%
# What to do if ME is missing?
crsp['melag'] = crsp.groupby('permno').melag_nt.fillna(method='pad')

# Fill na after delisting
#df = post_event_nan(df=df, event=df.lag_dlret.notnull(), vars=['melag'], id_vars=['permno', 'edate'])

# %% [markdown]
# ### Rankyear

# %%
# Portfolios are rebalanced in the end of june
crsp['rankyear'] = crsp.date.dt.year
crsp.loc[crsp.date.dt.month <= 6, 'rankyear'] = crsp.loc[crsp.date.dt.month <= 6, 'rankyear'] - 1

# %% [markdown]
# ## Add Risk Free

# %%
# Dowload the data
#%% Import Data
query = "SELECT caldt as date, t30ret as rf FROM crspq.mcti"
rf = db.raw_sql(query, date_cols=['date'])

# %%
rf.head()
# Out:
#         date        rf
# 0 1925-12-31       NaN
# 1 1926-01-30  0.002951
# 2 1926-02-27  0.002768
# 3 1926-03-31  0.002778
# 4 1926-04-30  0.003072

# %%
# Month dates: dates do not match directly to the ones in CRSP
rf['mdate'] = rf.date.dt.year*100+rf.date.dt.month

# %%
rf.drop(columns=['date'], inplace=True)

# %%
crsp['mdate']=crsp.date.dt.year*100+crsp.date.dt.month

# %%
crsp = pd.merge(crsp, rf, on=['mdate'])

# %%
crsp.rf.isnull().sum()
# Out:
# 0

# %%
crsp.columns
# Out:
# Index(['date', 'permno', 'permco', 'prc', 'vol', 'ret', 'retx', 'cfacpr',
#        'cfacshr', 'comnam', 'dlret', 'dlretx', 'exchcd', 'naics', 'cusip',
#        'ncusip', 'shrcd', 'shrout', 'siccd', 'ticker', 'retadj', 'me', 'mesum',
#        'melag_nt', 'melag', 'rankyear', 'mdate', 'rf'],
#       dtype='object')

# %% [markdown]
# ## Save Output

# %%
crsp.head()
# Out:
#         date  permno  permco  prc  vol  ret  retx  cfacpr  cfacshr comnam  \
# 0 1985-12-31   10000  7952.0  NaN  NaN  NaN   NaN     NaN      NaN    NaN
# 1 1985-12-31   10001  7953.0  NaN  NaN  NaN   NaN     NaN      NaN    NaN
# 2 1985-12-31   10002  7954.0  NaN  NaN  NaN   NaN     NaN      NaN    NaN
# 3 1985-12-31   10003  7957.0  NaN  NaN  NaN   NaN     NaN      NaN    NaN
# 4 1985-12-31   10005  7961.0  NaN  NaN  NaN   NaN     NaN      NaN    NaN
#
#    ...  siccd  ticker  retadj  me mesum melag_nt  melag  rankyear   mdate  \
# 0  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
# 1  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
# 2  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
# 3  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
# 4  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
#
#          rf
# 0  0.006139
# 1  0.006139
# 2  0.006139
# 3  0.006139
# 4  0.006139
#
# [5 rows x 28 columns]

# %%
# Make sure to change the path here for the place you want to save the data in your computer. 
crsp.to_pickle(path='/Users/rk2941/Dropbox/courses/big_data_2022/lecture_outputs/crsp_montly.pkl')
